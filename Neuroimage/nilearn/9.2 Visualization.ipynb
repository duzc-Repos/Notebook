# %%
from nilearn import datasets
from nilearn import plotting

# %% [markdown]
# # 1. Glass brain

# %%
moter_images = datasets.fetch_neurovault_motor_task()
stat_img = moter_images.images[0]
plotting.plot_glass_brain(stat_img, threshold=3, 
                          display_mode='lyrz')
plotting.show()

# %% [markdown]
# # 3. Atlas plotting

# %%
## retrieving the atlas data
dataset_ho = datasets.fetch_atlas_harvard_oxford('cort-maxprob-thr25-2mm')
dataset_ju = datasets.fetch_atlas_juelich('maxprob-thr0-1mm')
# Out:
# Dataset created in /home/duzc/nilearn_data/fsl
#
# ...
# Downloaded 3424256 of 25716861 bytes (13.3%, 29.9min remaining)Error while fetching file HarvardOxford.tgz; dataset fetching aborted.
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /mnt/d/software_for_wsl2/miniconda3/lib/python3.8/site-packages/urllib3/response.py in _error_catcher(self)
#     435             try:
# --> 436                 yield
#     437
#
# /mnt/d/software_for_wsl2/miniconda3/lib/python3.8/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     517                 cache_content = False
# --> 518                 data = self._fp.read(amt) if not fp_closed else b""
#     519                 if (
#
# /mnt/d/software_for_wsl2/miniconda3/lib/python3.8/http/client.py in read(self, amt)
#     457             b = bytearray(amt)
# --> 458             n = self.readinto(b)
# ...

# %% [markdown]
# # 1. Glass brain
